# %%
import app
import os
import matplotlib.pyplot as plt
import rasterio.plot as rplt
import rasterio
import numpy as np
import geopandas as gpd

app.setup_logger(use_console_handler=True, use_file_handler=True)

# %%
all_years = ["2016", "2018", "2019", "2020", "2022", "2023"]
all_lakes = []
for year in all_years:
    drainage_path = os.path.join(r"D:\PhD\21_Experiments\TidesDamageDriver\02_processed\01_drainages", year)
    lakes = gpd.read_file(os.path.join(drainage_path, f"{year}_drainages_0.shp"))
    all_lakes.append(lakes)
    print(f"{lakes.shape[0]:03d} lakes in {year}")
# Out:
# 049 lakes in 2016
# 012 lakes in 2018
# 080 lakes in 2019
# 032 lakes in 2020
# 001 lakes in 2022
# 000 lakes in 2023
