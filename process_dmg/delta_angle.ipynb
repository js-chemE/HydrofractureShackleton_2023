# %%
import app
import matplotlib.pyplot as plt

# %%
path_vx = r"C:\Users\jsommer1\[Code]\HydrofractureShackleton_2023\process_dmg\sample_data\tile-181_vx.tif"
path_vy = r"C:\Users\jsommer1\[Code]\HydrofractureShackleton_2023\process_dmg\sample_data\tile-181_vx.tif"
path_alpha_c = r"C:\Users\jsommer1\[Code]\HydrofractureShackleton_2023\process_dmg\sample_data\damage_detection\geotiffs_python\tile-181_S1_20151101_20151110_30m_output_10px_alphaC.tif"

results = app.dmg.calculate_delta_velocity_fracture(
    file_vx=path_vx,
    file_vy=path_vy,
    file_alpha_c=path_alpha_c
)
results.export(
    basename="tile-181_S1_20151101_20151110_30m_output_10px",
    path=r"C:\Users\jsommer1\[Code]\HydrofractureShackleton_2023\process_dmg\sample_data\damage_detection\geotiffs_python"
)

# %%
results.delta_alpha
# Out:
# <xarray.DataArray (band: 1, y: 9, x: 9)> Size: 648B
# array([[[115.,   9., 104.,  28.,   7.,  76., -26.,  95.,   7.],
#         [ -6., 100.,  55.,  25.,  90., -24., 115.,  -9.,   0.],
#         [-11., 102.,  39., 115.,  81.,   1.,  66.,  25.,  97.],
#         [ 66.,  47., 122.,  76.,  85., 102., 102.,  41.,  25.],
#         [109.,  66.,  12.,  -4.,  25.,  71.,  79.,  66., 100.],
#         [114.,   1.,  12.,  88.,  61., 102.,  66.,  -9.,  40.],
#         [  1., -11.,  63.,  13.,  40.,  16.,  17.,  59., 123.],
#         [100.,   3., 100.,  10.,  86.,  51., 115.,   3.,  71.],
#         [-22., -39.,  31.,  10., 115., -33.,  10., 123.,  21.]]])
# Coordinates:
#   * band         (band) int64 8B 1
#     spatial_ref  int64 8B 0
#   * x            (x) float64 72B 2.541e+06 2.541e+06 ... 2.543e+06 2.543e+06
#   * y            (y) float64 72B -4.648e+05 -4.651e+05 ... -4.669e+05 -4.672e+05
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
# ...
