# %%
import app
import logging

app.setup_logger()

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
path = r"D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg\2021"
path2threshold = r"C:\Users\jsommer1\[Code]\HydrofractureShackleton_2023\process_dmg"
app.dmg.run_nerd_folder(
    folder=path,
    img_res = 30,
    dbmin = -15,
    dbmax = 5,
    wsize = 10,
    cores = 10,
    path2threshold=path2threshold,
    overwrite=True,
)
# Out:
# .. Loaded  threshold 0.05 --> calculate dmg

# %%
image_path = r"C:\Users\jsommer1\[Code]\HydrofractureShackleton_2023\process_dmg\sample_data\tile-181_S1_20151101_20151110_30m.tif"
app.dmg.run_nerd(
    image_path=image_path,
    img_res = 30,
    dbmin = -15,
    dbmax = 5,
    wsize = 10,
    cores = 10,
    path2threshold=path2threshold,
    overwrite=True,
)
# Out:
# .. Loaded  threshold 0.05 --> calculate dmg
