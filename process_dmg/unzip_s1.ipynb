# %%
import app
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import app
#
# File ~\[Code]\HydrofractureShackleton_2023\app\__init__.py:6
#       4 from app.drainages import *
#       5 from app.tides import *
# ----> 6 import app.dmg as dmg
#       7 import app.files as files
#       9 ENVIRONMENT = read_config()
#
# File ~\[Code]\HydrofractureShackleton_2023\app\dmg\__init__.py:2
#       1 import app.dmg.nerd as nerd
# ----> 2 from app.dmg.nerd_process import nerd_process
#
# ModuleNotFoundError: No module named 'app.dmg.nerd_process'

# %%
folder = r"D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg"
app.files.unpack_zips_in_folder(folder)
# Out:
# Moved tile-187_S1_20201101_20201110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Moved tile-182_S1_20171101_20171110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Moved tile-181_S1_20201101_20201110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Moved tile-183_S1_20171101_20171110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Moved tile-187_S1_20191101_20191110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Moved tile-183_S1_20201101_20201110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Unpacked ee_damage_shackleton_S1_30m-20250414T190621Z-006.zip successfully.
# Moved tile-182_S1_20151101_20151110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# Moved tile-181_S1_20161101_20161110_30m.tif to D:\PhD\21_Experiments\TidesDamageDriver\01_raw\S1-dmg
# ...
